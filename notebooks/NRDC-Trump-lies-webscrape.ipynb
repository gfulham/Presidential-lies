# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.nrdc.org/trump-lies"
r = requests.get(url)

# %%
print(r.text[:500])
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]>
# <html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]>
# <html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]>
# <html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]>
# <html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!-->
# <html  lang="en" dir="ltr" prefix="fb: http://www.facebook.com/2008/fbml og: http://ogp.me/ns# article: http://ogp.me/n

# %%
soup = BeautifulSoup(r.text, "html.parser") # what text and how to parse the text into an object
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IEMobile 7]>
# <html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]>
# <html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]>
# <html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]>
# <html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!-->
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"><!--<![endif]-->
# <head>
# ...

# %%
<div>
<h4>Lie</h4>
<p><b>“I’m not denying climate change. But it could very well go back.”</b><br/>—October 11, 2018, interview on <em><a href="https://www.cbsnews.com/news/donald-trump-full-interview-60-minutes-transcript-lesley-stahl-2018-10-14/">60 Minutes</a></em>, following both Hurricane Michael and the release of the <a href="https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html">latest IPCC report</a></p>
<div class="video-filter"><iframe allowfullscreen="true" class="video-filter video-youtube vf-q25szuvmzmk" frameborder="0" height="336" src="//www.youtube.com/embed/Q25SZuvmZmk?modestbranding=0&amp;html5=1&amp;rel=0&amp;autoplay=0&amp;wmode=opaque&amp;loop=0&amp;controls=1&amp;autohide=0&amp;showinfo=0&amp;theme=dark&amp;color=red&amp;enablejsapi=0" width="645"></iframe></div>
<h4>Reality</h4>
<p>Scientists are unequivocal on this point: Climate change isn’t “going back.” It will never reverse itself. We can only limit how much and how fast the climate changes by reversing the thing that’s driving the change in the first place: <a href="https://www.nrdc.org/stories/global-warming-101">heat-trapping greenhouse gas pollution</a> in our atmosphere, largely from the burning of fossil fuels. We have to reduce those emissions dramatically in the next 10 years and reach net-zero emissions by 2050, primarily by shifting to clean energy and by protecting and enhancing the natural ecosystems that remove those pollutants from the air. Emissions from industry, transportation, and other human activities since the beginning of the 19th century are driving far more rapid climate change than any <a href="https://earthobservatory.nasa.gov/blogs/climateqa/if-earth-has-warmed-and-cooled-throughout-history-what-makes-scientists-think-that-humans-are-causing-global-warming-now/">natural variations</a> in the earth’s warming and cooling cycles, which occur over thousands and thousands of years—not one or two centuries. </p>
<p>Even the government’s own scientists agree. The U.S. government signed the <a href="https://www.nrdc.org/experts/roland-hwang/ipcc-report-isnt-death-knell-its-wake-call">recent report</a> from the Intergovernmental Panel on Climate Change, which urges drastic action to contain the man-made—and rapidly approaching—climate catastrophe. And in the <a href="https://www.nytimes.com/interactive/2017/11/03/climate/document-Climate-Science-Special-Report-2017.html">National Climate Assessment Report</a>, approved by the White House and released last November, federal officials specifically discount theories on natural cycles, saying they “find no convincing evidence that natural variability can account for the amount of global warming observed over the industrial era.” In other words, we shouldn’t hold our breath for a miracle reversal.</p>
<p>And for the record: If you deny both the cause (people) and the future projections (bleak) of climate change, then yes, you are a climate change denier. </p>
<hr/>
</div>
# Out:
#   File "<ipython-input-6-2936fc3263b2>", line 1
#     <div>
#     ^
# SyntaxError: invalid syntax

# %%
soup.h4
# Out:
# <h4>Lie</h4>

# %%
lies = soup.find_all("b")
lies
# Out:
# [<b>“I’m not denying climate change. But it could very well go back.”</b>,
#  <b>“I will say this. I don’t want to give trillions and trillions of dollars. I don’t want to lose millions and millions of jobs. I don’t want to be put at a disadvantage.”</b>,
#  <b>“Look, scientists also have a political agenda.”</b>,
#  <b>“The ice caps were going to melt. They were going to melt. They were going to be gone by now, but now they’re setting records, so OK, they’re at a record level.”</b>,
#  <b>“I have a very open mind about it. We’re going to look at it very carefully. It’s one issue that’s interesting because there are few things where there’s more division than climate change” and “It’s a very complex subject. I’m not sure anybody is ever going to really know.”</b>,
#  <b>“[T]he United States will withdraw from the Paris climate accord . . . but begin negotiations to reenter either the Paris accord or a really entirely new transaction.”</b>,
# ...

# %%
len(lies)
# Out:
# 66

# %%
lies[0].text
# Out:
# '“I’m not denying climate change. But it could very well go back.”'

# %%
lies[0].text[1:-1]
# Out:
# 'I’m not denying climate change. But it could very well go back.'

# %%
records = []
for each in lies:
    lie = each.text[1:-1]
    records.append(lie)

# %%
records
# Out:
# ['I’m not denying climate change. But it could very well go back.',
#  'I will say this. I don’t want to give trillions and trillions of dollars. I don’t want to lose millions and millions of jobs. I don’t want to be put at a disadvantage.',
#  'Look, scientists also have a political agenda.',
#  'The ice caps were going to melt. They were going to melt. They were going to be gone by now, but now they’re setting records, so OK, they’re at a record level.',
#  'I have a very open mind about it. We’re going to look at it very carefully. It’s one issue that’s interesting because there are few things where there’s more division than climate change” and\xa0“It’s a very complex subject. I’m not sure anybody is ever going to really know.',
#  '[T]he United States will withdraw from the Paris climate accord . . . but begin negotiations to reenter either the Paris accord or a really entirely new transaction.',
# ...

# %%
df = pd.DataFrame(records, columns = ["Lie"])
df
# Out:
#                                                   Lie
# 0   I’m not denying climate change. But it could v...
# 1   I will say this. I don’t want to give trillion...
# 2      Look, scientists also have a political agenda.
# 3   The ice caps were going to melt. They were goi...
# 4   I have a very open mind about it. We’re going ...
# ..                                                ...
# 61  We have seen how this tragic federal overreach...
# 62  Our precious national treasures must be protec...
# 63    Public lands will once again be for public use.
# 64  I’ve spoken with many state and local leaders―...
# 65  That’s a hoax...Under that deal, everybody in ...
#
# [66 rows x 1 columns]

# %%
 df.to_csv('NRDC-trump_lies.csv', index = False, encoding= 'utf-8')
